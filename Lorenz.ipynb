# %% [markdown]
# <a href="https://colab.research.google.com/github/arturitolc/IA/blob/main/Lorenz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

# %%
def lorenz(t, X, sigma=11, beta=8/3, rho=28):
  #Definimos el Sistema
    x, y, z = X
    dxdt = sigma * (y - x)
    dydt = x * (rho - z) - y
    dzdt = x * y - beta * z
    return [dxdt, dydt, dzdt]

# %%
# Condiciones iniciales y tiempo
X0 = [1.0, 1.0, 1.0]
t_span = (0, 50)
t_eval = np.linspace(*t_span, 10000)

#Solución numerica
sol = solve_ivp(lorenz, t_span, X0, t_eval=t_eval)

# %%
fig = plt.figure() #Grafica correspondiente
ax = fig.add_subplot(111, projection='3d')
ax.plot(sol.y[0], sol.y[1], sol.y[2])
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('Atractor de Lorenz')
plt.show()
